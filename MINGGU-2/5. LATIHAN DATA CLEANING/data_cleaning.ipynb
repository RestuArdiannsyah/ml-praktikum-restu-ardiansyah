# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Hands-ON

# %% [markdown]
# ##### source dataset: https://www.kaggle.com/datasets/utkarshx27/movies-dataset

# %% [markdown]
# ##### Import Libary

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Load Data

# %%
data = pd.read_csv("movie_dataset.csv")
data.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2         spy based on novel secret agent sequel mi6                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ... runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...   162.0
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...   169.0
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...   148.0
# 3  Following the death of District Attorney Harve...  112.312950  ...   165.0
# 4  John Carter is a war-weary, former military ca...   43.926995  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...
#
#                                                 crew           director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### Periksa datanya masing masing variabl/collom/fitur dengan dtypes

# %%
print(data.dtypes)
# Out:
# index                     int64
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# cast                     object
# crew                     object
# director                 object
# dtype: object

# %% [markdown]
# ##### Melihat Statistik dasar

# %%
data.describe()
# Out:
#              index        budget             id   popularity       revenue  \
# count  4803.000000  4.803000e+03    4803.000000  4803.000000  4.803000e+03
# mean   2401.000000  2.904504e+07   57165.484281    21.492301  8.226064e+07
# std    1386.651002  4.072239e+07   88694.614033    31.816650  1.628571e+08
# min       0.000000  0.000000e+00       5.000000     0.000000  0.000000e+00
# 25%    1200.500000  7.900000e+05    9014.500000     4.668070  0.000000e+00
# 50%    2401.000000  1.500000e+07   14629.000000    12.921594  1.917000e+07
# 75%    3601.500000  4.000000e+07   58610.500000    28.313505  9.291719e+07
# max    4802.000000  3.800000e+08  459488.000000   875.581305  2.787965e+09
#
#            runtime  vote_average    vote_count
# count  4801.000000   4803.000000   4803.000000
# mean    106.875859      6.092172    690.217989
# std      22.611935      1.194612   1234.585891
# min       0.000000      0.000000      0.000000
# 25%      94.000000      5.600000     54.000000
# 50%     103.000000      6.200000    235.000000
# 75%     118.000000      6.800000    737.000000
# max     338.000000     10.000000  13752.000000

# %% [markdown]
# ## Membuang Drop Kolom

# %% [markdown]
# ##### Melihat pada entri pertama

# %%
data.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2         spy based on novel secret agent sequel mi6                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ... runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...   162.0
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...   169.0
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...   148.0
# 3  Following the death of District Attorney Harve...  112.312950  ...   165.0
# 4  John Carter is a war-weary, former military ca...   43.926995  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...
#
#                                                 crew           director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### Memilih Kolom yang akan di drop

# %%
kolom_drop = [col for col in ['homepage', 'index', 'keywords', 'overview', 
                             'production_companies',
                             'spoken_languages', 'status', 'tagline',
                             'cast', 'crew'] 
              if col in data.columns]

# %% [markdown]
# ##### Melakukan drop pada data yang dipilih

# %%
data.drop(kolom_drop, inplace=True, axis=1)

# %% [markdown]
# ##### inspeksi ulang dataframe, kolom yang tidak diinginkan dibuang

# %%
data.head()
# Out:
#       budget                                    genres      id  \
# 0  237000000  Action Adventure Fantasy Science Fiction   19995
# 1  300000000                  Adventure Fantasy Action     285
# 2  245000000                    Action Adventure Crime  206647
# 3  250000000               Action Crime Drama Thriller   49026
# 4  260000000          Action Adventure Science Fiction   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises  112.312950
# 4                en                               John Carter   43.926995
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                     title  vote_average  \
# 0    162.0                                    Avatar           7.2
# 1    169.0  Pirates of the Caribbean: At World's End           6.9
# 2    148.0                                   Spectre           6.3
# 3    165.0                     The Dark Knight Rises           7.6
# 4    132.0                               John Carter           6.1
#
#    vote_count           director
# 0       11800      James Cameron
# 1        4500     Gore Verbinski
# 2        4466         Sam Mendes
# 3        9106  Christopher Nolan
# 4        2124     Andrew Stanton

# %% [markdown]
# ## Mengubah id di dataframe

# %% [markdown]
# ##### cek nilai untuk id

# %%
data['id'].is_unique
# Out:
# True

# %% [markdown]
# ##### ganti id yang ada pada kolom menggunakan set_index

# %%
data = data.set_index('id')
data.head()
# Out:
#            budget                                    genres original_language  \
# id
# 19995   237000000  Action Adventure Fantasy Science Fiction                en
# 285     300000000                  Adventure Fantasy Action                en
# 206647  245000000                    Action Adventure Crime                en
# 49026   250000000               Action Crime Drama Thriller                en
# 49529   260000000          Action Adventure Science Fiction                en
#
#                                   original_title  popularity  \
# id
# 19995                                     Avatar  150.437577
# 285     Pirates of the Caribbean: At World's End  139.082615
# 206647                                   Spectre  107.376788
# 49026                      The Dark Knight Rises  112.312950
# 49529                                John Carter   43.926995
#
#                                      production_countries release_date  \
# id
# 19995   [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 285     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 206647  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 49026   [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 49529   [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
#
#            revenue  runtime                                     title  \
# id
# 19995   2787965087    162.0                                    Avatar
# 285      961000000    169.0  Pirates of the Caribbean: At World's End
# 206647   880674609    148.0                                   Spectre
# 49026   1084939099    165.0                     The Dark Knight Rises
# 49529    284139100    132.0                               John Carter
#
#         vote_average  vote_count           director
# id
# 19995            7.2       11800      James Cameron
# 285              6.9        4500     Gore Verbinski
# 206647           6.3        4466         Sam Mendes
# 49026            7.6        9106  Christopher Nolan
# 49529            6.1        2124     Andrew Stanton

# %% [markdown]
# ##### Akses record ke 19995

# %%
data.loc[19995]
# Out:
# budget                                                          237000000
# genres                           Action Adventure Fantasy Science Fiction
# original_language                                                      en
# original_title                                                     Avatar
# popularity                                                     150.437577
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# runtime                                                             162.0
# title                                                              Avatar
# vote_average                                                          7.2
# vote_count                                                          11800
# director                                                    James Cameron
# Name: 19995, dtype: object

# %% [markdown]
# # Merapihkan fields dalam data

# %% [markdown]
# ##### Menghitung frekuensi nilai object

# %%
data.dtypes.value_counts()
# Out:
# object     7
# int64      3
# float64    3
# Name: count, dtype: int64

# %% [markdown]
# ##### seleksi data dari 1995 dengan output hanya pada field release_date

# %%
data.loc[1995:, 'release_date'].head(10)
# Out:
# id
# 1995      2001-06-11
# 157353    2014-04-16
# 331       2001-07-18
# 61791     2011-08-03
# 8204      2008-02-14
# 47964     2013-02-06
# 10733     2004-04-07
# 9806      2004-11-05
# 1408      1995-12-22
# 32657     2010-02-01
# Name: release_date, dtype: object

# %% [markdown]
# ##### enggunakan ekspresi reguler (Regex) tunggal untuk mengekstrak tahun publikasi

# %%
regex = r'^(\d{4})'

# %% [markdown]
# ##### jalankan regex di dataset

# %%
extr = data['release_date'].str.extract(r'^(\d{4})', expand=False)
extr.head()
# Out:
# id
# 19995     2009
# 285       2007
# 206647    2015
# 49026     2012
# 49529     2012
# Name: release_date, dtype: object

# %% [markdown]
# ##### mendapatkan versi numeriknya dengan perintah pd.to_numeric

# %%
data['release_date'] = pd.to_numeric(extr)
data['release_date'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ##### perhitungan pada nilai valid yang tersisa

# %%
data['release_date'].isnull().sum() / len(data)
# Out:
# np.float64(0.00020820320632937748)

# %% [markdown]
# ## Membersihkan Kolom dengan Kombinasi metode str dengan NumPy

# %% [markdown]
# ##### isi kolom 'production_countries'

# %%
data['production_countries'].head(10)
# Out:
# id
# 19995     [{"iso_3166_1": "US", "name": "United States o...
# 285       [{"iso_3166_1": "US", "name": "United States o...
# 206647    [{"iso_3166_1": "GB", "name": "United Kingdom"...
# 49026     [{"iso_3166_1": "US", "name": "United States o...
# 49529     [{"iso_3166_1": "US", "name": "United States o...
# 559       [{"iso_3166_1": "US", "name": "United States o...
# 38757     [{"iso_3166_1": "US", "name": "United States o...
# 99861     [{"iso_3166_1": "US", "name": "United States o...
# 767       [{"iso_3166_1": "GB", "name": "United Kingdom"...
# 209112    [{"iso_3166_1": "US", "name": "United States o...
# Name: production_countries, dtype: object

# %%
data.loc[1452]
# Out:
# budget                                                          270000000
# genres                           Adventure Fantasy Action Science Fiction
# original_language                                                      en
# original_title                                           Superman Returns
# popularity                                                      57.925623
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                       2006.0
# revenue                                                         391081192
# runtime                                                             154.0
# title                                                    Superman Returns
# vote_average                                                          5.4
# vote_count                                                           1400
# director                                                     Bryan Singer
# Name: 1452, dtype: object

# %% [markdown]
# ##### Mendapatkan bolean mask

# %%
pc = data['production_countries']
united_states = pc.str.contains('United States of America')
united_states[:5]
# Out:
# id
# 19995     True
# 285       True
# 206647    True
# 49026     True
# 49529     True
# Name: production_countries, dtype: bool

# %%
france = pc.str.contains('France')

# %% [markdown]
# ##### Kombinasikan dengan np.where:

# %%
data['production_countries'] = np.where(united_states, 'United States of America',
                                      np.where(france, 'France',
                                               pc.str.replace('-', ' ')))
data['production_countries'].head()
# Out:
# id
# 19995     United States of America
# 285       United States of America
# 206647    United States of America
# 49026     United States of America
# 49529     United States of America
# Name: production_countries, dtype: object

# %% [markdown]
# ##### tampilkan data

# %%
data.head()
# Out:
#            budget                                    genres original_language  \
# id
# 19995   237000000  Action Adventure Fantasy Science Fiction                en
# 285     300000000                  Adventure Fantasy Action                en
# 206647  245000000                    Action Adventure Crime                en
# 49026   250000000               Action Crime Drama Thriller                en
# 49529   260000000          Action Adventure Science Fiction                en
#
#                                   original_title  popularity  \
# id
# 19995                                     Avatar  150.437577
# 285     Pirates of the Caribbean: At World's End  139.082615
# 206647                                   Spectre  107.376788
# 49026                      The Dark Knight Rises  112.312950
# 49529                                John Carter   43.926995
#
#             production_countries  release_date     revenue  runtime  \
# id
# 19995   United States of America        2009.0  2787965087    162.0
# 285     United States of America        2007.0   961000000    169.0
# 206647  United States of America        2015.0   880674609    148.0
# 49026   United States of America        2012.0  1084939099    165.0
# 49529   United States of America        2012.0   284139100    132.0
#
#                                            title  vote_average  vote_count  \
# id
# 19995                                     Avatar           7.2       11800
# 285     Pirates of the Caribbean: At World's End           6.9        4500
# 206647                                   Spectre           6.3        4466
# 49026                      The Dark Knight Rises           7.6        9106
# 49529                                John Carter           6.1        2124
#
#                  director
# id
# 19995       James Cameron
# 285        Gore Verbinski
# 206647         Sam Mendes
# 49026   Christopher Nolan
# 49529      Andrew Stanton
